# %% [markdown]
# <a href="https://colab.research.google.com/github/SHRESHTH121/DL/blob/main/DL_4ProblemWithPerceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
or_data=pd.DataFrame()

# %%
or_data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
and_data=pd.DataFrame()
xor_data=pd.DataFrame()

# %%
or_data['input1']=[1,1,0,0]
or_data['input2']=[1,0,1,0]
or_data['output']=[1,1,1,0]

# %%
and_data['input1']=[1,1,0,0]
and_data['input2']=[1,0,1,0]
and_data['output']=[1,0,0,0]

# %%
xor_data['input1']=[1,1,0,0]
xor_data['input2']=[1,0,1,0]
xor_data['output']=[0,1,1,0]

# %%
or_data
# Out:
#    input1  input2  output
# 0       1       1       1
# 1       1       0       1
# 2       0       1       1
# 3       0       0       0

# %%
plt.scatter(or_data['input1'],or_data['input2'],c=or_data['output'],s=200)

plt.show()

# %%
sns.scatterplot(x=and_data['input1'],y=and_data['input2'],hue=and_data['output'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
sns.scatterplot(x=xor_data['input1'],y=xor_data['input2'],hue=xor_data['output'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
from sklearn.linear_model import Perceptron

# %%
clf1=Perceptron()
clf2=Perceptron()
clf3=Perceptron()

# %%
clf1.fit(or_data[['input1','input2']],or_data['output'])
clf2.fit(and_data[['input1','input2']],and_data['output'])
clf3.fit(xor_data[['input1','input2']],xor_data['output'])
# Out:
# Perceptron()

# %%
clf1.coef_
# Out:
# array([[2., 2.]])

# %%
clf1.intercept_
# Out:
# array([-1.])

# %%
clf2.coef_
# Out:
# array([[2., 2.]])

# %%
clf2.intercept_
# Out:
# array([-2.])

# %%
clf3.coef_
# Out:
# array([[0., 0.]])

# %%
clf3.intercept_
# Out:
# array([0.])

# %%
X=np.linspace(0,1,5)

# %%
y=-X+1

# %%
plt.plot(X,y)
plt.scatter(or_data['input1'],or_data['input2'],c=or_data['output'],s=200)
plt.show()

# %%
plt.plot(X,y)
plt.scatter(and_data['input1'],and_data['input2'],c=and_data['output'],s=200)
plt.show()

# %%
def plot_decision_region(X, y, classifier, resolution=0.02):
    from matplotlib.colors import ListedColormap
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0],
                    y=X[y == cl, 1],
                    alpha=0.8,
                    c=colors[idx],
                    marker=markers[idx],
                    label=cl,
                    edgecolor='black')
    plt.title('XOR Gate Decision Region')
    plt.xlabel('Input 1')
    plt.ylabel('Input 2')
    plt.legend(loc='upper left')
    plt.show()

plot_decision_region(xor_data[['input1','input2']].values,xor_data['output'].values,clf3)
